# %%
import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %% [markdown]
# **Loading the data**

# %%
df = pd.read_csv('temp/Final_Dataset.csv')
df = df.sample(frac = 1)
df
# Out:
#         Unnamed: 0                                            tx_hash  \
# 269361      269361  0b9051b1e30dc289a3c9385bb3d8a5413e75c2e9d63fd7...
# 713982      713982  a37411bc648e1ba3fe73fe11428bd313ada305a9bd1021...
# 943179      943179  800bffc221ea91b39a23d4b19f124e35fe8e9809384006...
# 139871      139871  8eec059e8e7daf9706e1c1f6bbd01d2a243ea4ca1b08e2...
# 700212      700212  eaa7d6ec71bc092c3154a6a8e2250b3537fe8fac69ab0c...
# ...            ...                                                ...
# 443473      443473  9a1aca06e7462d3c6c5f89426b9f5d963d3c03cf4d53d4...
# 481806      481806  9e1d09568bd6c8d01cdf999bd51197fd79ed4698c1222e...
# 790175      790175  89f15eac581790dbb4e96f41d49c100702c0f3175c78f6...
# 500978      500978  3a49f54cd61ae60094e27a90efbb1a4c7989fa938bb9b0...
# 545523      545523  6d8f29564a6a351ab2646569b7b927c3db154dddac3389...
#
#         indegree  outdegree      in_btc   out_btc    total_btc  mean_in_btc  \
# 269361       1.0        1.0   10.830000   10.7700    21.600000    10.830000
# 713982       9.0        1.0   15.610443   15.6100    31.220443     1.734494
# 943179       1.0        2.0    3.390000    3.3895     6.779500     3.390000
# 139871       1.0        1.0    0.010000    0.0100     0.020000     0.010000
# 700212       1.0        2.0  100.000000  100.0000   200.000000   100.000000
# ...          ...        ...         ...       ...          ...          ...
# 443473       1.0        2.0   10.260000   10.2600    20.520000    10.260000
# 481806       1.0        1.0    5.230000    5.2300    10.460000     5.230000
# 790175       1.0        2.0  992.200000  992.2000  1984.400000   992.200000
# 500978       1.0        2.0   16.490000   16.4800    32.970000    16.490000
# 545523       1.0        2.0   64.332000   64.3320   128.664000    64.332000
#
#         mean_out_btc  in_malicious  out_malicious  is_malicious  \
# 269361      10.77000           0.0            0.0           0.0
# 713982      15.61000           0.0            0.0           0.0
# 943179       1.69475           0.0            0.0           0.0
# 139871       0.01000           0.0            0.0           0.0
# 700212      50.00000           0.0            0.0           0.0
# ...              ...           ...            ...           ...
# 443473       5.13000           0.0            0.0           0.0
# 481806       5.23000           0.0            0.0           0.0
# 790175     496.10000           0.0            0.0           0.0
# 500978       8.24000           0.0            0.0           0.0
# 545523      32.16600           0.0            0.0           0.0
#
#         all_malicious  out_and_tx_malicious
# 269361            0.0                   0.0
# 713982            0.0                   0.0
# 943179            0.0                   0.0
# 139871            0.0                   0.0
# 700212            0.0                   0.0
# ...               ...                   ...
# 443473            0.0                   0.0
# 481806            0.0                   0.0
# 790175            0.0                   0.0
# 500978            0.0                   0.0
# 545523            0.0                   0.0
#
# [1000105 rows x 14 columns]

# %%
df.shape
# Out:
# (1000105, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0      indegree     outdegree        in_btc       out_btc  \
# count  1.000105e+06  1.000105e+06  1.000105e+06  1.000105e+06  1.000105e+06
# mean   4.999440e+05  1.581877e+00  1.823178e+00  1.475096e+02  1.508677e+02
# std    2.887056e+05  5.261233e+00  5.102122e+00  2.323695e+03  2.320377e+03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.499180e+05  1.000000e+00  1.000000e+00  3.000000e-01  1.200000e+00
# 50%    4.999440e+05  1.000000e+00  2.000000e+00  9.899800e+00  2.082000e+01
# 75%    7.499700e+05  1.000000e+00  2.000000e+00  4.857000e+01  5.000000e+01
# max    9.999960e+05  9.650000e+02  9.220000e+02  4.420000e+05  4.420000e+05
#
#           total_btc   mean_in_btc  mean_out_btc  in_malicious  out_malicious  \
# count  1.000105e+06  1.000105e+06  1.000105e+06  1.000105e+06   1.000105e+06
# mean   2.983773e+02  1.330834e+02  9.000626e+01  5.099465e-04   6.499318e-05
# std    4.615422e+03  2.107230e+03  1.384711e+03  2.257625e-02   8.061577e-03
# min    5.993300e-04  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    2.660000e+00  2.000000e-01  9.200000e-01  0.000000e+00   0.000000e+00
# 50%    4.302000e+01  7.200000e+00  1.143653e+01  0.000000e+00   0.000000e+00
# 75%    9.688000e+01  4.617000e+01  5.000000e+01  0.000000e+00   0.000000e+00
# max    8.840000e+05  4.321099e+05  4.000000e+05  1.000000e+00   1.000000e+00
#
#        is_malicious  all_malicious  out_and_tx_malicious
# count  1.000105e+06   1.000105e+06          1.000105e+06
# mean   4.699507e-05   6.139355e-04          1.079887e-04
# std    6.855137e-03   2.477013e-02          1.039120e-02
# min    0.000000e+00   0.000000e+00          0.000000e+00
# 25%    0.000000e+00   0.000000e+00          0.000000e+00
# 50%    0.000000e+00   0.000000e+00          0.000000e+00
# 75%    0.000000e+00   0.000000e+00          0.000000e+00
# max    1.000000e+00   1.000000e+00          1.000000e+00

# %% [markdown]
# **Drop unnecessary columns**

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('tx_hash', axis=1, inplace=True)
df.drop('in_malicious', axis=1, inplace=True)
df.drop('out_malicious', axis=1, inplace=True)
df.drop('is_malicious', axis=1, inplace=True)
df.drop('all_malicious', axis=1, inplace=True)

# %%
print('No Frauds', round(df['out_and_tx_malicious'].value_counts()[0]/len(df) * 100,7), '% of the dataset')
print('Frauds', round(df['out_and_tx_malicious'].value_counts()[1]/len(df) * 100,5), '% of the dataset')
# Out:
# No Frauds 99.9892011 % of the dataset
# Frauds 0.0108 % of the dataset

# %%
df['out_and_tx_malicious'].value_counts()
# Out:
# 0.0    999997
# 1.0       108
# Name: out_and_tx_malicious, dtype: int64

# %% [markdown]
# **Scaled Transform**

# %%
import sklearn as sk
# Log scale to normalize the data
scaled_df = df.copy()

scaled_df['indegree'] = np.log1p(scaled_df['indegree'])
scaled_df['outdegree']= np.log1p(scaled_df['outdegree'])
scaled_df['in_btc'] = np.log1p(scaled_df['in_btc'])
scaled_df['out_btc']= np.log1p(scaled_df['out_btc'])
scaled_df['total_btc']= np.log1p(scaled_df['total_btc'])
scaled_df['mean_in_btc']= np.log1p(scaled_df['mean_in_btc'])
scaled_df['mean_out_btc']= np.log1p(scaled_df['mean_out_btc'])

# RobustScaler is less prone to outliers.
from sklearn.preprocessing import RobustScaler
rob_scaler = RobustScaler()

scaled_df['indegree'] = rob_scaler.fit_transform(scaled_df['indegree'].values.reshape(-1,1))
scaled_df['outdegree'] = rob_scaler.fit_transform(scaled_df['outdegree'].values.reshape(-1,1))
scaled_df['in_btc'] = rob_scaler.fit_transform(scaled_df['in_btc'].values.reshape(-1,1))
scaled_df['out_btc'] = rob_scaler.fit_transform(scaled_df['out_btc'].values.reshape(-1,1))
scaled_df['total_btc'] = rob_scaler.fit_transform(scaled_df['total_btc'].values.reshape(-1,1))
scaled_df['mean_in_btc'] = rob_scaler.fit_transform(scaled_df['mean_in_btc'].values.reshape(-1,1))
scaled_df['mean_out_btc'] = rob_scaler.fit_transform(scaled_df['mean_out_btc'].values.reshape(-1,1))

# %%
scaled_df
# Out:
#         indegree  outdegree    in_btc   out_btc  total_btc  mean_in_btc  \
# 269361  0.000000       -1.0  0.022492 -0.196373  -0.202872     0.099826
# 713982  1.609438       -1.0  0.115706 -0.086793  -0.094953    -0.299117
# 943179  0.000000        0.0 -0.249769 -0.510157  -0.527390    -0.170180
# 139871  0.000000       -1.0 -0.653332 -0.977574  -1.145624    -0.570399
# 700212  0.000000        0.0  0.611470  0.487469   0.462122     0.683925
# ...          ...        ...       ...       ...        ...          ...
# 443473  0.000000        0.0  0.008929 -0.210465  -0.217773     0.086376
# 481806  0.000000       -1.0 -0.153629 -0.398760  -0.409515    -0.074837
# 790175  0.000000        0.0  1.239264  1.214654   1.159041     1.306518
# 500978  0.000000        0.0  0.129877 -0.070552  -0.078863     0.206321
# 545523  0.000000        0.0  0.491823  0.348879   0.328731     0.565269
#
#         mean_out_btc  out_and_tx_malicious
# 269361     -0.016797                   0.0
# 713982      0.088235                   0.0
# 943179     -0.466331                   0.0
# 139871     -0.765570                   0.0
# 700212      0.430306                   0.0
# ...              ...                   ...
# 443473     -0.215717                   0.0
# 481806     -0.210783                   0.0
# 790175      1.124608                   0.0
# 500978     -0.090592                   0.0
# 545523      0.299096                   0.0
#
# [1000105 rows x 8 columns]

# %%
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from pylab import rcParams
from sklearn.metrics import silhouette_score
from sklearn.cluster import MiniBatchKMeans
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# **Split training and testing data**

# %%
original_Xtrain, original_Xtest, original_ytrain, original_ytest = train_test_split(scaled_df.iloc[:,:-1], scaled_df['out_and_tx_malicious'], test_size = 0.2, random_state=2)

# %%
original_ytest
# Out:
# 37728     0.0
# 955752    0.0
# 72248     0.0
# 332190    0.0
# 128997    0.0
#          ...
# 718785    0.0
# 120553    0.0
# 563180    0.0
# 867693    0.0
# 352615    0.0
# Name: out_and_tx_malicious, Length: 200021, dtype: float64

# %%
original_Xtrain
# Out:
#         indegree  outdegree    in_btc   out_btc  total_btc  mean_in_btc  \
# 7368   -0.693147       -1.0 -0.656064  0.270092   0.044787    -0.573109
# 166498  0.000000       -1.0 -0.620078 -0.939056  -1.076532    -0.537421
# 376806  0.000000        0.0 -0.009480 -0.231789  -0.239151     0.068119
# 548273  0.693147        0.0 -0.264549 -0.528006  -0.546332    -0.377147
# 167004  0.000000        0.0  0.958983  0.889999   0.848232     1.028558
# ...          ...        ...       ...       ...        ...          ...
# 551172  0.000000        0.0  0.755407  0.654193   0.622213     0.826669
# 851638  0.000000        0.0 -0.624939 -0.944687  -1.086193    -0.542242
# 593850  0.000000        0.0 -0.462960 -0.758642  -0.814320    -0.381604
# 473122  0.405465        0.0 -0.437030 -0.728465  -0.776588    -0.443396
# 303211  0.000000        0.0  0.248316  0.066821   0.055572     0.323779
#
#         mean_out_btc
# 7368        0.430306
# 166498     -0.728651
# 376806     -0.234436
# 548273     -0.480192
# 167004      0.813973
# ...              ...
# 551172      0.588888
# 851638     -0.750837
# 593850     -0.643953
# 473122     -0.624337
# 303211      0.035236
#
# [800084 rows x 7 columns]

# %% [markdown]
# **Oversampling trainig data**

# %%
from imblearn.over_sampling import SMOTE

SM = SMOTE(random_state=42)
original_Xtrain, original_ytrain  = SM.fit_resample(original_Xtrain, original_ytrain)

# %%
# models = {}
# sse = {}

# for k in range(2, 30):
#     kmeans = MiniBatchKMeans(init='k-means++', n_clusters=k, n_init=1000, max_iter=15000, batch_size=256)
#     kmeans.fit(original_Xtrain)    
#     models[k] = kmeans    
#     labels = kmeans.labels_
#     sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
#     print("\nDone with k = "+str(k))

# %%
# plt.style.use('seaborn')

# #Sum of distances of samples to their closest cluster center
# plt.figure(figsize=(10,7))
# plt.plot(list(sse.keys()), list(sse.values()))
# plt.xticks(list(sse.keys()))
# plt.xlabel("Number of cluster")
# plt.ylabel("Sum of squared distances")

# plt.show()

# %% [markdown]
# **Train Model**

# %%
models = {}
sse = {}


for k in range(2, 13):
    kmeans = MiniBatchKMeans(init='k-means++', n_clusters=k, n_init=1000, max_iter=15000, batch_size=256)
    kmeans.fit(original_Xtrain)    
    models[k] = kmeans    
    labels = kmeans.labels_
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
    print("\nDone with k = "+str(k))
# Out:
# Done with k = 2
#
# Done with k = 3
#
# Done with k = 4
#
# Done with k = 5
#
# Done with k = 6
#
# Done with k = 7
#
# Done with k = 8
#
# Done with k = 9
#
# Done with k = 10
#
# Done with k = 11
#
# Done with k = 12

# %%
plt.style.use('seaborn')

#Sum of distances of samples to their closest cluster center
plt.figure(figsize=(10,7))
plt.plot(list(sse.keys()), list(sse.values()))
plt.xticks(list(sse.keys()))
plt.xlabel("Number of cluster")
plt.ylabel("Sum of squared distances")

plt.show()

# %% [markdown]
# **Save Model**

# %%
for k in models:
    pickle.dump(models.get(k), open('./Models/Kmeans/k='+str(k)+'.h5', 'wb'))

# %% [markdown]
# **Train data evaluation**

# %%
train_predictions = {}
normal_count = pd.value_counts(original_ytrain)[0]
fraud_count = pd.value_counts(original_ytrain)[1]
for k in models:
    print('Model with K='+str(k)+'\n'+'=================================\n')
    train_predictions[k] = models.get(k).predict(original_Xtrain)

    print("Predicted for K="+str(k))
    loc = 0
    countdict = {}
    m_locs = set(np.where(original_ytrain == 1)[0])
    for pred in train_predictions[k]:
        countdict[pred] = countdict.get(pred, 0) + 0
        if loc in m_locs:
            countdict[pred] = countdict.get(pred, 0) + 1
        loc = loc + 1
    for key, value in sorted(countdict.items()):
        non_mal = len((np.where(train_predictions[k] == key)[0]))-value
        print('Cluster '+str(key+1)+': \t Malicious: '+str(value)+ ' ('+str(round((value*100)/fraud_count,3))+'%)' +' \t Non-Malicious: '+str(non_mal)+' ('+str(round((non_mal*100)/normal_count,3))+'%)\n')
    print('\n')
# Out:
# Model with K=2
# =================================
#
# Predicted for K=2
# Cluster 1: 	 Malicious: 372852 (46.607%) 	 Non-Malicious: 738351 (92.294%)
#
# Cluster 2: 	 Malicious: 427145 (53.393%) 	 Non-Malicious: 61646 (7.706%)
#
#
#
# Model with K=3
# =================================
#
# Predicted for K=3
# Cluster 1: 	 Malicious: 384368 (48.046%) 	 Non-Malicious: 21622 (2.703%)
#
# Cluster 2: 	 Malicious: 324386 (40.548%) 	 Non-Malicious: 461333 (57.667%)
#
# Cluster 3: 	 Malicious: 91243 (11.405%) 	 Non-Malicious: 317042 (39.63%)
#
#
#
# Model with K=4
# =================================
#
# Predicted for K=4
# Cluster 1: 	 Malicious: 304566 (38.071%) 	 Non-Malicious: 453718 (56.715%)
#
# Cluster 2: 	 Malicious: 105591 (13.199%) 	 Non-Malicious: 3342 (0.418%)
#
# Cluster 3: 	 Malicious: 90622 (11.328%) 	 Non-Malicious: 311118 (38.89%)
#
# Cluster 4: 	 Malicious: 299218 (37.402%) 	 Non-Malicious: 31819 (3.977%)
#
#
#
# Model with K=5
# =================================
#
# Predicted for K=5
# Cluster 1: 	 Malicious: 313581 (39.198%) 	 Non-Malicious: 365427 (45.679%)
#
# Cluster 2: 	 Malicious: 230397 (28.8%) 	 Non-Malicious: 3532 (0.442%)
#
# Cluster 3: 	 Malicious: 91317 (11.415%) 	 Non-Malicious: 318142 (39.768%)
#
# Cluster 4: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 74132 (9.267%)
#
# Cluster 5: 	 Malicious: 164702 (20.588%) 	 Non-Malicious: 38764 (4.846%)
#
#
#
# Model with K=6
# =================================
#
# Predicted for K=6
# Cluster 1: 	 Malicious: 211489 (26.436%) 	 Non-Malicious: 4827 (0.603%)
#
# Cluster 2: 	 Malicious: 239678 (29.96%) 	 Non-Malicious: 391667 (48.959%)
#
# Cluster 3: 	 Malicious: 89790 (11.224%) 	 Non-Malicious: 301876 (37.735%)
#
# Cluster 4: 	 Malicious: 90436 (11.305%) 	 Non-Malicious: 19742 (2.468%)
#
# Cluster 5: 	 Malicious: 77198 (9.65%) 	 Non-Malicious: 997 (0.125%)
#
# Cluster 6: 	 Malicious: 91406 (11.426%) 	 Non-Malicious: 80888 (10.111%)
#
#
#
# Model with K=7
# =================================
#
# Predicted for K=7
# Cluster 1: 	 Malicious: 229260 (28.658%) 	 Non-Malicious: 259969 (32.496%)
#
# Cluster 2: 	 Malicious: 205265 (25.658%) 	 Non-Malicious: 3944 (0.493%)
#
# Cluster 3: 	 Malicious: 90508 (11.314%) 	 Non-Malicious: 305690 (38.211%)
#
# Cluster 4: 	 Malicious: 85547 (10.693%) 	 Non-Malicious: 96073 (12.009%)
#
# Cluster 5: 	 Malicious: 97869 (12.234%) 	 Non-Malicious: 58088 (7.261%)
#
# Cluster 6: 	 Malicious: 91548 (11.444%) 	 Non-Malicious: 2240 (0.28%)
#
# Cluster 7: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 73993 (9.249%)
#
#
#
# Model with K=8
# =================================
#
# Predicted for K=8
# Cluster 1: 	 Malicious: 88160 (11.02%) 	 Non-Malicious: 20436 (2.555%)
#
# Cluster 2: 	 Malicious: 84940 (10.618%) 	 Non-Malicious: 258415 (32.302%)
#
# Cluster 3: 	 Malicious: 208859 (26.107%) 	 Non-Malicious: 4498 (0.562%)
#
# Cluster 4: 	 Malicious: 196147 (24.518%) 	 Non-Malicious: 236092 (29.512%)
#
# Cluster 5: 	 Malicious: 77664 (9.708%) 	 Non-Malicious: 1091 (0.136%)
#
# Cluster 6: 	 Malicious: 84600 (10.575%) 	 Non-Malicious: 56934 (7.117%)
#
# Cluster 7: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 74092 (9.262%)
#
# Cluster 8: 	 Malicious: 59627 (7.453%) 	 Non-Malicious: 148439 (18.555%)
#
#
#
# Model with K=9
# =================================
#
# Predicted for K=9
# Cluster 1: 	 Malicious: 65409 (8.176%) 	 Non-Malicious: 124788 (15.599%)
#
# Cluster 2: 	 Malicious: 63701 (7.963%) 	 Non-Malicious: 155126 (19.391%)
#
# Cluster 3: 	 Malicious: 204796 (25.6%) 	 Non-Malicious: 4182 (0.523%)
#
# Cluster 4: 	 Malicious: 86609 (10.826%) 	 Non-Malicious: 50509 (6.314%)
#
# Cluster 5: 	 Malicious: 76931 (9.616%) 	 Non-Malicious: 978 (0.122%)
#
# Cluster 6: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 74023 (9.253%)
#
# Cluster 7: 	 Malicious: 86975 (10.872%) 	 Non-Malicious: 17160 (2.145%)
#
# Cluster 8: 	 Malicious: 21381 (2.673%) 	 Non-Malicious: 150412 (18.802%)
#
# Cluster 9: 	 Malicious: 194195 (24.274%) 	 Non-Malicious: 222819 (27.852%)
#
#
#
# Model with K=10
# =================================
#
# Predicted for K=10
# Cluster 1: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 74076 (9.26%)
#
# Cluster 2: 	 Malicious: 77581 (9.698%) 	 Non-Malicious: 18494 (2.312%)
#
# Cluster 3: 	 Malicious: 68485 (8.561%) 	 Non-Malicious: 162435 (20.304%)
#
# Cluster 4: 	 Malicious: 72802 (9.1%) 	 Non-Malicious: 920 (0.115%)
#
# Cluster 5: 	 Malicious: 60801 (7.6%) 	 Non-Malicious: 4782 (0.598%)
#
# Cluster 6: 	 Malicious: 22977 (2.872%) 	 Non-Malicious: 155438 (19.43%)
#
# Cluster 7: 	 Malicious: 243012 (30.377%) 	 Non-Malicious: 311813 (38.977%)
#
# Cluster 8: 	 Malicious: 85246 (10.656%) 	 Non-Malicious: 68831 (8.604%)
#
# Cluster 9: 	 Malicious: 152482 (19.06%) 	 Non-Malicious: 827 (0.103%)
#
# Cluster 10: 	 Malicious: 16611 (2.076%) 	 Non-Malicious: 2381 (0.298%)
#
#
#
# Model with K=11
# =================================
#
# Predicted for K=11
# Cluster 1: 	 Malicious: 116451 (14.556%) 	 Non-Malicious: 130287 (16.286%)
#
# Cluster 2: 	 Malicious: 67187 (8.398%) 	 Non-Malicious: 146950 (18.369%)
#
# Cluster 3: 	 Malicious: 166247 (20.781%) 	 Non-Malicious: 533 (0.067%)
#
# Cluster 4: 	 Malicious: 48554 (6.069%) 	 Non-Malicious: 6095 (0.762%)
#
# Cluster 5: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 74063 (9.258%)
#
# Cluster 6: 	 Malicious: 47632 (5.954%) 	 Non-Malicious: 14924 (1.866%)
#
# Cluster 7: 	 Malicious: 64030 (8.004%) 	 Non-Malicious: 4065 (0.508%)
#
# Cluster 8: 	 Malicious: 136362 (17.045%) 	 Non-Malicious: 232822 (29.103%)
#
# Cluster 9: 	 Malicious: 45413 (5.677%) 	 Non-Malicious: 649 (0.081%)
#
# Cluster 10: 	 Malicious: 85749 (10.719%) 	 Non-Malicious: 36847 (4.606%)
#
# Cluster 11: 	 Malicious: 22372 (2.797%) 	 Non-Malicious: 152762 (19.095%)
#
#
#
# Model with K=12
# =================================
#
# Predicted for K=12
# Cluster 1: 	 Malicious: 151425 (18.928%) 	 Non-Malicious: 792 (0.099%)
#
# Cluster 2: 	 Malicious: 59354 (7.419%) 	 Non-Malicious: 126909 (15.864%)
#
# Cluster 3: 	 Malicious: 21846 (2.731%) 	 Non-Malicious: 147259 (18.407%)
#
# Cluster 4: 	 Malicious: 81393 (10.174%) 	 Non-Malicious: 33417 (4.177%)
#
# Cluster 5: 	 Malicious: 105177 (13.147%) 	 Non-Malicious: 145968 (18.246%)
#
# Cluster 6: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 73826 (9.228%)
#
# Cluster 7: 	 Malicious: 73052 (9.132%) 	 Non-Malicious: 910 (0.114%)
#
# Cluster 8: 	 Malicious: 59321 (7.415%) 	 Non-Malicious: 4341 (0.543%)
#
# Cluster 9: 	 Malicious: 64351 (8.044%) 	 Non-Malicious: 119663 (14.958%)
#
# Cluster 10: 	 Malicious: 86304 (10.788%) 	 Non-Malicious: 60660 (7.583%)
#
# Cluster 11: 	 Malicious: 75507 (9.438%) 	 Non-Malicious: 12639 (1.58%)
#
# Cluster 12: 	 Malicious: 22267 (2.783%) 	 Non-Malicious: 73613 (9.202%)

# %% [markdown]
# **Test data evaluation**

# %%
predictions = {}
normal_count = pd.value_counts(original_ytest)[0]
fraud_count = pd.value_counts(original_ytest)[1]
for k in models:
    print('Model with K='+str(k)+'\n'+'=================================\n')
    predictions[k] = models.get(k).predict(original_Xtest)
    print("Predicted for K="+str(k))
    loc = 0
    countdict = {}
    m_locs = set(np.where(original_ytest == 1)[0])
    for pred in predictions[k]:
        countdict[pred] = countdict.get(pred, 0) + 0
        if loc in m_locs:
            countdict[pred] = countdict.get(pred, 0) + 1
        loc = loc + 1
    for key, value in sorted(countdict.items()):
        non_mal = len((np.where(predictions[k] == key)[0]))-value
        print('Cluster '+str(key+1)+': \t Malicious: '+str(value)+ ' ('+str(round((value*100)/fraud_count,3))+'%)' +' \t Non-Malicious: '+str(non_mal)+' ('+str(round((non_mal*100)/normal_count,3))+'%)\n')
    print('\n')
# Out:
# Model with K=2
# =================================
#
# Predicted for K=2
# Cluster 1: 	 Malicious: 13 (61.905%) 	 Non-Malicious: 184375 (92.188%)
#
# Cluster 2: 	 Malicious: 8 (38.095%) 	 Non-Malicious: 15625 (7.812%)
#
#
#
# Model with K=3
# =================================
#
# Predicted for K=3
# Cluster 1: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 5515 (2.758%)
#
# Cluster 2: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 115102 (57.551%)
#
# Cluster 3: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 79383 (39.692%)
#
#
#
# Model with K=4
# =================================
#
# Predicted for K=4
# Cluster 1: 	 Malicious: 6 (28.571%) 	 Non-Malicious: 113079 (56.54%)
#
# Cluster 2: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 893 (0.446%)
#
# Cluster 3: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 77958 (38.979%)
#
# Cluster 4: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 8070 (4.035%)
#
#
#
# Model with K=5
# =================================
#
# Predicted for K=5
# Cluster 1: 	 Malicious: 6 (28.571%) 	 Non-Malicious: 91259 (45.63%)
#
# Cluster 2: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 953 (0.476%)
#
# Cluster 3: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 79624 (39.812%)
#
# Cluster 4: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18373 (9.186%)
#
# Cluster 5: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 9791 (4.896%)
#
#
#
# Model with K=6
# =================================
#
# Predicted for K=6
# Cluster 1: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 1233 (0.616%)
#
# Cluster 2: 	 Malicious: 5 (23.81%) 	 Non-Malicious: 97322 (48.661%)
#
# Cluster 3: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 75695 (37.848%)
#
# Cluster 4: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 4997 (2.498%)
#
# Cluster 5: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 292 (0.146%)
#
# Cluster 6: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 20461 (10.23%)
#
#
#
# Model with K=7
# =================================
#
# Predicted for K=7
# Cluster 1: 	 Malicious: 5 (23.81%) 	 Non-Malicious: 64807 (32.404%)
#
# Cluster 2: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 996 (0.498%)
#
# Cluster 3: 	 Malicious: 7 (33.333%) 	 Non-Malicious: 76587 (38.294%)
#
# Cluster 4: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 24001 (12.0%)
#
# Cluster 5: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 14643 (7.322%)
#
# Cluster 6: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 623 (0.312%)
#
# Cluster 7: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18343 (9.172%)
#
#
#
# Model with K=8
# =================================
#
# Predicted for K=8
# Cluster 1: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 5161 (2.58%)
#
# Cluster 2: 	 Malicious: 6 (28.571%) 	 Non-Malicious: 64709 (32.354%)
#
# Cluster 3: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 1151 (0.576%)
#
# Cluster 4: 	 Malicious: 5 (23.81%) 	 Non-Malicious: 58974 (29.487%)
#
# Cluster 5: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 313 (0.156%)
#
# Cluster 6: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 14368 (7.184%)
#
# Cluster 7: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18368 (9.184%)
#
# Cluster 8: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 36956 (18.478%)
#
#
#
# Model with K=9
# =================================
#
# Predicted for K=9
# Cluster 1: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 31263 (15.632%)
#
# Cluster 2: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 38600 (19.3%)
#
# Cluster 3: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 1054 (0.527%)
#
# Cluster 4: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 12769 (6.384%)
#
# Cluster 5: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 288 (0.144%)
#
# Cluster 6: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18353 (9.176%)
#
# Cluster 7: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 4400 (2.2%)
#
# Cluster 8: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 37733 (18.866%)
#
# Cluster 9: 	 Malicious: 5 (23.81%) 	 Non-Malicious: 55540 (27.77%)
#
#
#
# Model with K=10
# =================================
#
# Predicted for K=10
# Cluster 1: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18362 (9.181%)
#
# Cluster 2: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 4700 (2.35%)
#
# Cluster 3: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 40495 (20.248%)
#
# Cluster 4: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 264 (0.132%)
#
# Cluster 5: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 1218 (0.609%)
#
# Cluster 6: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 39034 (19.517%)
#
# Cluster 7: 	 Malicious: 5 (23.81%) 	 Non-Malicious: 77793 (38.896%)
#
# Cluster 8: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 17320 (8.66%)
#
# Cluster 9: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 212 (0.106%)
#
# Cluster 10: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 602 (0.301%)
#
#
#
# Model with K=11
# =================================
#
# Predicted for K=11
# Cluster 1: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 32679 (16.34%)
#
# Cluster 2: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 36820 (18.41%)
#
# Cluster 3: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 134 (0.067%)
#
# Cluster 4: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 1568 (0.784%)
#
# Cluster 5: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18360 (9.18%)
#
# Cluster 6: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 3720 (1.86%)
#
# Cluster 7: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 1033 (0.516%)
#
# Cluster 8: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 57778 (28.889%)
#
# Cluster 9: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 199 (0.1%)
#
# Cluster 10: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 9307 (4.654%)
#
# Cluster 11: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 38402 (19.201%)
#
#
#
# Model with K=12
# =================================
#
# Predicted for K=12
# Cluster 1: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 207 (0.104%)
#
# Cluster 2: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 31475 (15.738%)
#
# Cluster 3: 	 Malicious: 4 (19.048%) 	 Non-Malicious: 36936 (18.468%)
#
# Cluster 4: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 8445 (4.222%)
#
# Cluster 5: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 36390 (18.195%)
#
# Cluster 6: 	 Malicious: 0 (0.0%) 	 Non-Malicious: 18305 (9.152%)
#
# Cluster 7: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 260 (0.13%)
#
# Cluster 8: 	 Malicious: 3 (14.286%) 	 Non-Malicious: 1094 (0.547%)
#
# Cluster 9: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 29970 (14.985%)
#
# Cluster 10: 	 Malicious: 2 (9.524%) 	 Non-Malicious: 15322 (7.661%)
#
# Cluster 11: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 3177 (1.588%)
#
# Cluster 12: 	 Malicious: 1 (4.762%) 	 Non-Malicious: 18419 (9.21%)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import balanced_accuracy_score

def evaluation_summary(test_y, predictions, clf_name):
    print('For ' + clf_name)
    print('Balanced Accuracy: '+ str(round(balanced_accuracy_score(test_y, predictions),7)))
    print('Macro Precision: '+ str(round(precision_score(test_y, predictions, average="macro"),7)))
    print('Macro Recall: '+ str(round(recall_score(test_y,predictions, average="macro"),7)))
    print('Macro F1: '+ str(round(f1_score(test_y,predictions, average="macro"),7)))
    print('\n')
    
    print('Normal Accuracy: '+ str(round(accuracy_score(test_y, predictions),7)))
    print('Normal Precision: '+ str(round(precision_score(test_y, predictions),7)))
    print('Normal Recall: '+ str(round(recall_score(test_y,predictions),7)))
    print('Normal F1: '+ str(round(f1_score(test_y,predictions),7)))
    print('\n')
    print(classification_report(test_y, predictions, labels=[0, 1]))
    print('\n')

# %%
def conf_matrix_percent(conf_matrix_train, conf_matrix_test):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    LABELS = ["Normal", "Fraud"]
    #Confusion Matrix Visual
    conf_matrix_train = conf_matrix_train.astype('float') / (conf_matrix_train.sum(axis=1)[:, np.newaxis])
    sns.heatmap(conf_matrix_train, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt=".0%", annot_kws={"size": 12}, ax=ax1)
    ax1.set_title("Training Confusion matrix")
    ax1.set_ylabel('True class')
    ax1.set_xlabel('Predicted class')
    
    conf_matrix_test = conf_matrix_test.astype('float') / (conf_matrix_test.sum(axis=1)[:, np.newaxis])
    sns.heatmap(conf_matrix_test, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt=".0%", annot_kws={"size": 12}, ax=ax2)
    ax2.set_title("Test Confusion matrix")
    ax2.set_ylabel('True class')
    ax2.set_xlabel('Predicted class')

# %%
def conf_matrix_normal(conf_matrix_train, conf_matrix_test):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    LABELS = ["Normal", "Fraud"]
#     conf_matrix_train = conf_matrix_train.astype('float') / (conf_matrix_train.sum(axis=1)[:, np.newaxis])
    sns.heatmap(conf_matrix_train, xticklabels=LABELS, yticklabels=LABELS, annot=True, annot_kws={"size": 12}, fmt="d", ax=ax1);
    ax1.set_title("Training Confusion matrix")
    ax1.set_ylabel('True class')
    ax1.set_xlabel('Predicted class')
    
#     conf_matrix_test = conf_matrix_test.astype('float') / (conf_matrix_test.sum(axis=1)[:, np.newaxis])
    sns.heatmap(conf_matrix_test, xticklabels=LABELS, yticklabels=LABELS, annot=True, annot_kws={"size": 12}, fmt="d", ax=ax2);
    ax2.set_title("Test Confusion matrix")
    ax2.set_ylabel('True class')
    ax2.set_xlabel('Predicted class')

# %%
k = 4
print('For K='+str(k))
merge = [4,2]

prediction = predictions[k].copy()
t_prediction = train_predictions[k].copy()


if len(pd.value_counts(t_prediction)) > 2 and len(pd.value_counts(prediction)) > 2:
    for i in range(0,k):
        if (i+1) in merge:
            prediction[prediction == i] = -1
            t_prediction[t_prediction == i] = -1
        else:
            prediction[prediction == i] = 0
            t_prediction[t_prediction == i] = 0

    prediction[prediction == -1] = 1
    t_prediction[t_prediction == -1] = 1

    print('Train Cluster Merge Result:\n')
    print(pd.value_counts(t_prediction))

    print('\n\nTest Cluster Merge Result:\n')
    print(pd.value_counts(prediction))
# Out:
# For K=4
# Train Cluster Merge Result:
#
# 0    1160024
# 1     439970
# dtype: int64
#
#
# Test Cluster Merge Result:
#
# 0    191050
# 1      8971
# dtype: int64

# %%
report = metrics.classification_report(original_ytrain, t_prediction) 
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.96      0.78    799997
#          1.0       0.92      0.51      0.65    799997
#
#     accuracy                           0.73   1599994
#    macro avg       0.79      0.73      0.72   1599994
# weighted avg       0.79      0.73      0.72   1599994

# %%
evaluation_summary(original_ytrain, t_prediction, 'K-means (K='+str(k)+')')
# Out:
# For K-means (K=4)
# Balanced Accuracy: 0.7310309
# Macro Precision: 0.7897055
# Macro Recall: 0.7310309
# Macro F1: 0.7166858
#
#
# Normal Accuracy: 0.7310309
# Normal Precision: 0.9200832
# Normal Recall: 0.5060131
# Normal F1: 0.6529351
#
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.96      0.78    799997
#            1       0.92      0.51      0.65    799997
#
#     accuracy                           0.73   1599994
#    macro avg       0.79      0.73      0.72   1599994
# weighted avg       0.79      0.73      0.72   1599994

# %%
evaluation_summary(original_ytest, prediction, 'K-means (K='+str(k)+')')
# Out:
# For K-means (K=4)
# Balanced Accuracy: 0.6680687
# Macro Precision: 0.5004119
# Macro Recall: 0.6680687
# Macro F1: 0.4894129
#
#
# Normal Accuracy: 0.9551247
# Normal Precision: 0.0008918
# Normal Recall: 0.3809524
# Normal F1: 0.0017794
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98    200000
#            1       0.00      0.38      0.00        21
#
#     accuracy                           0.96    200021
#    macro avg       0.50      0.67      0.49    200021
# weighted avg       1.00      0.96      0.98    200021

# %%
cnf_mtx_test = confusion_matrix(original_ytest, prediction)
cnf_mtx_train = confusion_matrix(original_ytrain, t_prediction)

# %%
cnf_mtx_train
# Out:
# array([[764836,  35161],
#        [395188, 404809]], dtype=int64)

# %%
cnf_mtx_test
# Out:
# array([[191037,   8963],
#        [    13,      8]], dtype=int64)

# %%
conf_matrix_percent(cnf_mtx_train, cnf_mtx_test)

# %%
conf_matrix_normal(cnf_mtx_train, cnf_mtx_test)
